# %%
# %matplotlib inline
import sys
sys.path.insert(0, '../')

from pylab import *
import numpy as np
import matplotlib.colors as colors
rcParams['font.size']=15

from Zodi import Zodi
zodi_model = Zodi('../')

# %%
zodi_model.plot_input_data()
# Out:
# Izod[12,0] 2.59e-06 90.0 0.0
# Izod[0,5] 9.85e-06 0.0 25.0
# self.get_zodi_500nm(solar_lat = 0., solar_lon =  0.) [0.01]
# self.get_zodi_500nm(solar_lat =  0., solar_lon = 90.) [2.59e-06]
# self.get_zodi_500nm(solar_lat =  0., solar_lon = 90.) [2.3e-06]
# self.get_zodi_500nm(solar_lat =  31.0, solar_lon =  50.8) [2.15784325e-06]
# self.get_zodi_500nm(solar_lat =  88.6, solar_lon =  58.9) [7.78223237e-07]
# self.get_zodi_500nm(solar_lat =  62.8, solar_lon =  19.1) [1.32602266e-06]
# self.get_zodi_500nm(solar_lat =  16.4, solar_lon =  107.4) [1.61573114e-06]
# self.get_zodi_500nm(solar_lat =  67.3, solar_lon =  155.9) [7.60583536e-07]
# self.get_zodi_500nm(solar_lat =  43.1, solar_lon =  169.3) [1.07428822e-06]
# self.get_zodi_500nm(solar_lat =  64.0, solar_lon =  73.4) [9.08550604e-07]
# self.get_zodi_500nm(solar_lat =  17.8, solar_lon =  4.2) [2.06854838e-05]
# self.get_zodi_500nm(solar_lat =  14.8, solar_lon =  111.4) [1.63978296e-06]
# ...

# %%
from Exozodi import Exozodi
exozodi_model = Exozodi()
